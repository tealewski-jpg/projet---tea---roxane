# %% [markdown]
# <center>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/6/6f/Dauphine_logo_2019_-_Bleu.png" style="width: 600px;"/>
# </center>

# %% [markdown]
# <div align="center"><span style="font-family:Arial Black;font-size:32px;color:darkblue">Python for finance</span></div>

# %% [markdown]
# # Optimisation de portefeuille

# %% [markdown]
# ## Modèle Moyenne – Variance de Markowitz

# %% [markdown]
# Au début des années 50, Harry Markowitz propose le critère d’analyse **moyenne – variance** et  dès lors il jette les bases de ce qui sera appelé plus tard la **Théorie moderne du portefeuille**. En effet, Markowitz part du principe que les rendements générés par un titre ou actif sont des variables aléatoires, ensuite <u> il propose les deux premiers moments à savoir la moyenne et la variance comme les critères de mesure respectifs de l’espérance et du risque perçus par un investisseur rationnel. </u>

# %% [markdown]
# L'optimisation d'un portefeuille consiste donc à chercher au sein d'un univers de titres donné, les valeurs et les proportions de valeurs permettant de constituer un portefeuille situé sur <u> **la frontière efficiente**</u>.

# %% [markdown]
# ## Manipulation de titres

# %% [markdown]
# On commence par importer nos librairies habituelles

# %%
#on peut utiliser yfinance si pandareader marche pas
import pandas as pd
import numpy as np
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #on peut utiliser yfinance si pandareader marche pas
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import datetime
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# On installe un nouveau module qui permet de télécharger les données direcement depuis des beses de données internet comme FRED, Yahoo Finance, Quandl ou Google Finance

# %% [markdown]
# **pip** est l’outil d’installation de prédilection. À partir de Python 3.4, il est inclus par défaut avec l’installateur de Python.

# %% [markdown]
# Il s'utilise directement sur l'invite de commandes, avec la syntaxe suivante
# > **pip install** *SomePackage*
#
# Pour utiliser des commandes "Shell", c'est à dire qui ont vocation à être utilisées dans un invite des commandes directement sur Jupyter, mettre un **point d'exclamation** au début de la cellule.
#
# > **! pip install** *SomePackage*
#
# Nous allons donc installer **pandas_datareader** et en importer le module ".data" sous alias web

# %%
# !pip3.11 install --upgrade yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/1e/60/462859de757ac56830824da7e8cf314b8b0321af5853df867c84cd6c2128/yfinance-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting pandas>=1.3.0 (from yfinance)
#   Obtaining dependency information for pandas>=1.3.0 from https://files.pythonhosted.org/packages/97/35/6411db530c618e0e0005187e35aa02ce60ae4c4c4d206964a2f978217c27/pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.16.5 (from yfinance)
#   Obtaining dependency information for numpy>=1.16.5 from https://files.pythonhosted.org/packages/28/34/b3fdcec6e725409223dd27356bdf5a3c2cc2282e428218ecc9cb7acc9763/numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl.metadata
#   Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# Collecting requests>=2.31 (from yfinance)
#   Obtaining dependency information for requests>=2.31 from https://files.pythonhosted.org/packages/d7/8e/7540e8a2036f79a125c1d2ebadf69ed7901608859186c856fa0388ef4197/requests-2.33.1-py3-none-any.whl.metadata
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/roxane/Library/Python/3.11/lib/python/site-packages (from yfinance) (4.9.4)
# Collecting pytz>=2022.5 (from yfinance)
#   Obtaining dependency information for pytz>=2022.5 from https://files.pythonhosted.org/packages/10/99/781fe0c827be2742bcc775efefccb3b048a3a9c6ce9aec0cbf4a101677e5/pytz-2026.1.post1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/38/74/f94141b38a51a553efef7f510fc213894161ae49b88bffd037f8d2a7cb2f/frozendict-2.4.7-py3-none-any.whl.metadata
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Obtaining dependency information for peewee>=3.16.2 from https://files.pythonhosted.org/packages/c0/9b/bee274b72adc7c692bf7cb8d6b0cd4071acf2957e82dace45d3f2770470e/peewee-4.0.4-py3-none-any.whl.metadata
#   Downloading peewee-4.0.4-py3-none-any.whl.metadata (8.6 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Obtaining dependency information for beautifulsoup4>=4.11.1 from https://files.pythonhosted.org/packages/1a/39/47f9197bdd44df24d67ac8893641e16f386c984a0619ef2ee4c51fbbc019/beautifulsoup4-4.14.3-py3-none-any.whl.metadata
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Obtaining dependency information for curl_cffi<0.14,>=0.7 from https://files.pythonhosted.org/packages/19/d1/acabfd460f1de26cad882e5ef344d9adde1507034528cb6f5698a2e6a2f1/curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl.metadata
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Obtaining dependency information for protobuf>=3.19.0 from https://files.pythonhosted.org/packages/ec/11/3325d41e6ee15bf1125654301211247b042563bcc898784351252549a8ad/protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Obtaining dependency information for websockets>=13.0 from https://files.pythonhosted.org/packages/f3/fa/abe89019d8d8815c8781e90d697dec52523fb8ebe308bf11664e8de1877e/websockets-16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading websockets-16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.1->yfinance)
#   Obtaining dependency information for soupsieve>=1.6.1 from https://files.pythonhosted.org/packages/46/2c/1462b1d0a634697ae9e55b3cecdcb64788e8b7d63f54d923fcd0bb140aed/soupsieve-2.8.3-py3-none-any.whl.metadata
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/roxane/Library/Python/3.11/lib/python/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting cffi>=1.12.0 (from curl_cffi<0.14,>=0.7->yfinance)
#   Obtaining dependency information for cffi>=1.12.0 from https://files.pythonhosted.org/packages/12/4a/3dfd5f7850cbf0d06dc84ba9aa00db766b52ca38d8b86e3a38314d52498c/cffi-2.0.0-cp311-cp311-macosx_10_13_x86_64.whl.metadata
#   Downloading cffi-2.0.0-cp311-cp311-macosx_10_13_x86_64.whl.metadata (2.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi<0.14,>=0.7->yfinance)
#   Obtaining dependency information for certifi>=2024.2.2 from https://files.pythonhosted.org/packages/9a/3c/c17fb3ca2d9c3acff52e30b309f538586f9f5b9c9cf454f3845fc9af4881/certifi-2026.2.25-py3-none-any.whl.metadata
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/roxane/Library/Python/3.11/lib/python/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/c2/d7/b5b7020a0565c2e9fa8c09f4b5fa6232feb326b8c20081ccded47ea368fd/charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/0e/61/66938bbb5fc52dbdf84594873d5b51fb1f7c7794e9c0f5bd885f30bc507b/idna-3.11-py3-none-any.whl.metadata
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.31->yfinance)
#   Obtaining dependency information for urllib3<3,>=1.26 from https://files.pythonhosted.org/packages/39/08/aaaad47bc4e9dc8c725e68f9d04865dbcb2052843ff09c97b08904852d84/urllib3-2.6.3-py3-none-any.whl.metadata
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/0c/c3/44f3fbbfa403ea2a7c779186dc20772604442dde72947e7d01069cbe98e3/pycparser-3.0-py3-none-any.whl.metadata
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: six>=1.5 in /Users/roxane/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Downloading yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 5.1 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 3.1 MB/s eta 0:00:00
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 14.3 MB/s eta 0:00:0000:0100:01
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 16.8 MB/s eta 0:00:0000:0100:01
# Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 19.0 MB/s eta 0:00:0000:010:01
# Downloading peewee-4.0.4-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 4.5 MB/s eta 0:00:00
# Downloading protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.2/429.2 kB 10.4 MB/s eta 0:00:0000:01
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 11.2 MB/s eta 0:00:0000:01
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 1.5 MB/s eta 0:00:00
# Downloading websockets-16.0-cp311-cp311-macosx_10_9_x86_64.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.0/175.0 kB 5.9 MB/s eta 0:00:00
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 5.9 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp311-cp311-macosx_10_13_x86_64.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 2.4 MB/s eta 0:00:00:00:01
# Downloading charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 10.2 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 2.0 MB/s eta 0:00:00
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 4.2 MB/s eta 0:00:00
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 618.7 kB/s eta 0:00:000:00:01
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15635 sha256=666da640a961660340a54c1ffafcde102773a75ea9e3dce242c9faa368d0730f
#   Stored in directory: /Users/roxane/Library/Caches/pip/wheels/42/d6/84/bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# Successfully built multitasking
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, soupsieve, pycparser, protobuf, numpy, idna, frozendict, charset_normalizer, certifi, requests, pandas, cffi, beautifulsoup4, curl_cffi, yfinance
# Successfully installed beautifulsoup4-4.14.3 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.7 curl_cffi-0.13.0 frozendict-2.4.7 idna-3.11 multitasking-0.0.12 numpy-2.4.4 pandas-3.0.2 peewee-4.0.4 protobuf-7.34.1 pycparser-3.0 pytz-2026.1.post1 requests-2.33.1 soupsieve-2.8.3 urllib3-2.6.3 websockets-16.0 yfinance-1.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip3.11 install --upgrade pip

# %% [markdown]
# Initialiser une valeur de stock, une date de fin et une date de début.

# %%
import datetime
import yfinance as yf

# cours de bourse de Tesla qui a pour ticker "TSLA"
tesla = yf.Ticker("TSLA")

# on choisit un an entier, la performance sur un an étant souvent prioritaire quand on optimise un portefeuille
date_debut = datetime.datetime(2021, 1, 1)
date_fin = datetime.datetime(2024, 1, 1)

# %% [markdown]
# Ecrivez la requête pour obtenir un cours de bourse, par exemple SPY

# %%
# obtention des données historiques pour Tesla du 01/01/2021 au 01/01/2024
data = tesla.history(start=date_debut, end=date_fin, interval="1d")

# %% [markdown]
# Affichez les données

# %%
# affichage des données
data
# la colonne date commence au 4 janvier car c'était le premier jour de bourse aux Etats-Unis en 2021
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  239.820007  248.163330  239.063339  243.256668
# 2021-01-05 00:00:00-05:00  241.220001  246.946671  239.733337  245.036667
# 2021-01-06 00:00:00-05:00  252.830002  258.000000  249.699997  251.993332
# 2021-01-07 00:00:00-05:00  259.209991  272.329987  258.399994  272.013336
# 2021-01-08 00:00:00-05:00  285.333344  294.829987  279.463318  293.339996
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00-05:00  256.760010  258.220001  251.369995  252.539993
# 2023-12-26 00:00:00-05:00  254.490005  257.970001  252.910004  256.609985
# 2023-12-27 00:00:00-05:00  258.350006  263.339996  257.519989  261.440002
# 2023-12-28 00:00:00-05:00  263.660004  265.130005  252.710007  253.179993
# 2023-12-29 00:00:00-05:00  255.100006  255.190002  247.429993  248.479996
#
#                               Volume  Dividends  Stock Splits
# Date
# 2021-01-04 00:00:00-05:00  145914600        0.0           0.0
# 2021-01-05 00:00:00-05:00   96735600        0.0           0.0
# 2021-01-06 00:00:00-05:00  134100000        0.0           0.0
# 2021-01-07 00:00:00-05:00  154496700        0.0           0.0
# 2021-01-08 00:00:00-05:00  225166500        0.0           0.0
# ...                              ...        ...           ...
# 2023-12-22 00:00:00-05:00   93370100        0.0           0.0
# 2023-12-26 00:00:00-05:00   86892400        0.0           0.0
# 2023-12-27 00:00:00-05:00  106494400        0.0           0.0
# 2023-12-28 00:00:00-05:00  113619900        0.0           0.0
# 2023-12-29 00:00:00-05:00  100891600        0.0           0.0
#
# [753 rows x 7 columns]

# %% [markdown]
# Récupération de la colonne contenant les prix de clôture

# %%
# récupération de la colonne "Close" car elle contient les prix de clôture
close_prices = data['Close']

# %% [markdown]
# Visusalisation des données

# %%
# affichage de la colonne des prix de clôture
print(close_prices)
# Out:
# Date
# 2021-01-04 00:00:00-05:00    243.256668
# 2021-01-05 00:00:00-05:00    245.036667
# 2021-01-06 00:00:00-05:00    251.993332
# 2021-01-07 00:00:00-05:00    272.013336
# 2021-01-08 00:00:00-05:00    293.339996
#                                 ...
# 2023-12-22 00:00:00-05:00    252.539993
# 2023-12-26 00:00:00-05:00    256.609985
# 2023-12-27 00:00:00-05:00    261.440002
# 2023-12-28 00:00:00-05:00    253.179993
# 2023-12-29 00:00:00-05:00    248.479996
# Name: Close, Length: 753, dtype: float64

# %% [markdown]
# On s'assure que les dates sont bien triées

# %%
# tri des données par les dates (d'où le index) dans l'ordre croissant
data_sorted = close_prices.sort_index()

# affichage des données triées qui s'avéraient être déjà triées au préalable
print(data_sorted)
# Out:
# Date
# 2021-01-04 00:00:00-05:00    243.256668
# 2021-01-05 00:00:00-05:00    245.036667
# 2021-01-06 00:00:00-05:00    251.993332
# 2021-01-07 00:00:00-05:00    272.013336
# 2021-01-08 00:00:00-05:00    293.339996
#                                 ...
# 2023-12-22 00:00:00-05:00    252.539993
# 2023-12-26 00:00:00-05:00    256.609985
# 2023-12-27 00:00:00-05:00    261.440002
# 2023-12-28 00:00:00-05:00    253.179993
# 2023-12-29 00:00:00-05:00    248.479996
# Name: Close, Length: 753, dtype: float64
